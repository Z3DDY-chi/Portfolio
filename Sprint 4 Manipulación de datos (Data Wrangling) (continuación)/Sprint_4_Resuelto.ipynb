# %% [markdown]
# # ¡Hola Eduardo! <a class="tocSkip"></a>
#
# Mi nombre es Oscar Flores y tengo el gusto de revisar tu proyecto. Si tienes algún comentario que quieras agregar en tus respuestas te puedes referir a mi como Oscar, no hay problema que me trates de tú.
#
# Si veo un error en la primera revisión solamente lo señalaré y dejaré que tú encuentres de qué se trata y cómo arreglarlo. Debo prepararte para que te desempeñes como especialista en Data, en un trabajo real, el responsable a cargo tuyo hará lo mismo. Si aún tienes dificultades para resolver esta tarea, te daré indicaciones más precisas en una siguiente iteración.
#
# Te dejaré mis comentarios más abajo - **por favor, no los muevas, modifiques o borres**
#
# Comenzaré mis comentarios con un resumen de los puntos que están bien, aquellos que debes corregir y aquellos que puedes mejorar. Luego deberás revisar todo el notebook para leer mis comentarios, los cuales estarán en rectángulos de color verde, amarillo o rojo como siguen:
#
# <div class='alert alert-block alert-success'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Muy bien! Toda la respuesta fue lograda satisfactoriamente.
# </div>
#
# <div class='alert alert-block alert-warning'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Existen detalles a mejorar. Existen recomendaciones.
# </div>
#
# <div class='alert alert-block alert-danger'>
#
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Se necesitan correcciones en el bloque. El trabajo no puede ser aceptado con comentarios en rojo sin solucionar.
# </div>
#
# Cualquier comentario que quieras agregar entre iteraciones de revisión lo puedes hacer de la siguiente manera:
#
#
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.</b> <a class='tocSkip'></a>
# </div>
#
#
#
# Mucho éxito en el proyecto!

# %% [markdown]
# ## Resumen de la revisión v1 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Hola Eduardo, ¿cómo va todo? Espero que estés teniendo una buena jornada.
#
# Buen trabajo completando todos los puntos del notebook. El proyecto en general está bien logrado, con una correcta implementación del código necesario. Solo falta revisar un par de errores en la parte de análisis de los nulos. Te dejé anotaciones en rojo con observaciones puntuales para que puedas hacer esos ajustes.
#
# Ante cualquier duda, no dudes en dejar un comentario en azul. Con gusto lo atenderé en la próxima iteración.
#
# Saludos!
#
#
# </div>

# %% [markdown]
# ## Resumen de la revisión v2 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor  v2 </b> <a class="tocSkip"></a>
#
# Bien hecho Eduardo, buen trabajo con las últimas correcciones. Has terminado completamente las tareas necesarias del notebook, no tengo comentarios de corrección adicionales, tu proyecto está aprobado. Los conocimientos que aplicaste aquí te serán muy útiles para análisis futuros, mucho éxito!
#
# Saludos!
#
# </div>

# %% [markdown]
# ----

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# El objetivo de este paso es cargar y comprender los conjuntos de datos que vamos a usar. Para ello, seguiremos estos pasos:
#
# Lectura de los archivos CSV:
# Usaremos pd.read_csv() para leer cada archivo (instacart_orders.csv, products.csv, order_products.csv, aisles.csv y departments.csv). Revisaremos si es necesario pasar parámetros adicionales como dtype para forzar el tipo de datos correcto o parse_dates si hay fechas.
#
# Inspección inicial de los DataFrames:
# Para cada DataFrame, verificaremos:
#
# La estructura y tipos de datos usando .info() para confirmar que las columnas se leyeron correctamente.
#
# Las primeras filas con .head() para entender el contenido y detectar posibles inconsistencias visibles.
#
# Detección preliminar de problemas:
# Durante esta inspección inicial, identificaremos:
#
# Valores ausentes o nulos en cada columna (.isnull().sum()).
#
# Posibles duplicados usando .duplicated().sum().
#
# Datos que no coincidan con el tipo esperado (por ejemplo, IDs que se leen como floats en lugar de enteros).
#
# Documentación de hallazgos:
# Anotaremos cualquier hallazgo relevante, como columnas con valores ausentes, duplicados o errores de tipo, ya que esto guiará los pasos posteriores de limpieza y preprocesamiento.

# %%
# importar librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# leer conjuntos de datos en los DataFrames
orders = pd.read_csv("/datasets/instacart_orders.csv", sep=";")
products = pd.read_csv("/datasets/products.csv", sep=";")
order_products = pd.read_csv("/datasets/order_products.csv", sep=";")
aisles = pd.read_csv("/datasets/aisles.csv", sep=";")
departments = pd.read_csv("/datasets/departments.csv", sep=";")

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor         </b> <a class="tocSkip"></a>
#
# Correcto. Bien hecho al importar la data usando el parámetro `sep=;"` para que la lectura de los datos se pueda realizar correctamente.
#
#
# </div>

# %%
# mostrar información del DataFrame
print("=== ORDERS ===")
orders.info(show_counts=True)
print(orders.head(), "\n")

# %%
# mostrar información del DataFrame
print("=== PRODUCTS ===")
products.info(show_counts=True)
print(products.head(), "\n")

# %%
# mostrar información del DataFrame
print("=== ORDER_PRODUCTS ===")
order_products.info(show_counts=True)
print(order_products.head(), "\n")

# %%
# mostrar información del DataFrame
print("=== AISLES ===")
aisles.info(show_counts=True)
print(aisles.head(), "\n")

# %%
# mostrar información del DataFrame
print("=== DEPARTMENTS ===")
departments.info(show_counts=True)
print(departments.head(), "\n")

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
#
# Correcto, muy bien con el uso de `head()` e `info()` para revisar las filas de los dataframes. Sin embargo, te recomiendo usar `show_counts=True` para `info()`, en el caso de que el dataframe tenga muchas filas, ya que si no, no aparecerá el detalle completo.
#
#
# </div>

# %% [markdown]
# ## Conclusiones
#
# Conclusiones
#
# Problema de delimitador:
# Todos los DataFrames (orders, products, order_products, aisles, departments) se cargaron con una sola columna que contiene todos los campos separados por ;. Esto indica que el parámetro sep no se configuró en pd.read_csv(). Por defecto, Pandas espera comas (,), pero estos archivos usan punto y coma (;). Esto se corregirá usando pd.read_csv('archivo.csv', sep=';').
#
# Tipos de datos:
# Actualmente, todas las columnas aparecen como object, porque están combinadas en una sola. Una vez que separemos correctamente las columnas, podremos asignar tipos adecuados:
#
# IDs (order_id, user_id, product_id, aisle_id, department_id) → int.
#
# Cantidades como add_to_cart_order → int.
#
# Bandera reordered → int.
#
# days_since_prior_order → float (ya que puede haber valores nulos o decimales).
#
# Tamaño y memoria:
#
# orders tiene 478,967 filas, lo que es manejable.
#
# products tiene 49,694 filas.
#
# order_products es el más grande, con 4,545,007 filas, por lo que operaciones pesadas deben hacerse con cuidado.
#
# aisles y departments son pequeños (134 y 21 filas), perfectos para usar como tablas de referencia.
#
# Valores ausentes y duplicados:
#
# Hasta ahora no hemos podido detectar valores ausentes por la forma incorrecta en que se cargaron los datos. Una vez corregido el delimitador y separados los campos, podremos usar .isnull().sum() y .duplicated().sum() para identificar estos problemas.
#
# Próximo paso:
# Antes de hacer cualquier análisis exploratorio o preprocesamiento, es indispensable recargar los archivos con el delimitador correcto (sep=';') y asignar los tipos de datos adecuados. Esto nos permitirá trabajar con DataFrames limpios y consistentes.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Verificación y corrección de tipos de datos
#
# Revisaremos los tipos de datos de cada DataFrame con .dtypes y .info().
#
# Nos aseguraremos de que los identificadores (order_id, user_id, product_id, aisle_id, department_id) sean de tipo entero.
#
# Si encontramos columnas que deberían ser categóricas (por ejemplo, order_dow, order_hour_of_day), las convertiremos a category para optimizar memoria y análisis.
#
# Identificación de valores ausentes
#
# Usaremos .isnull().sum() para cada DataFrame.
#
# Analizaremos qué columnas tienen valores faltantes y la proporción de estos valores.
#
# Para columnas críticas como days_since_prior_order, podemos decidir:
#
# Mantener el valor nulo como indicador de “primer pedido” (ya que el primer pedido no tiene un pedido previo).
#
# Rellenar con cero o con la media/mediana según el contexto.
#
# Columnas como IDs o nombres de productos no deberían tener valores ausentes; si los encontramos, consideraremos eliminarlos.
#
# Detección y eliminación de duplicados
#
# Aplicaremos .duplicated() a cada DataFrame.
#
# Si encontramos duplicados exactos, los eliminaremos con .drop_duplicates().
#
# Justificación: los duplicados pueden estar presentes por errores de extracción, exportación o limpieza previa del conjunto de datos. Eliminarlos asegura que cada pedido o producto sea contado solo una vez.
#
# Justificación de decisiones
#
# Las columnas de ID deben ser enteros para garantizar integridad y consistencia en merges posteriores.
#
# Los valores ausentes en days_since_prior_order indican que no hubo pedido previo; rellenarlos con cero o mantener como NaN tiene sentido según el análisis posterior.
#
# La eliminación de duplicados evita sesgos en conteos, agregaciones y análisis de reorden.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
duplicados_antes = orders.duplicated().sum()
duplicados = orders[orders.duplicated(keep=False)]
print(duplicados.sort_values(by='order_id'))
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 354993    391768    57671            19          3                  2
# 371905    391768    57671            19          3                  2
# 119251    408114    68324             4          3                  2
# 321100    408114    68324             4          3                  2
# 394347    467134    63189            21          3                  2
# 250626    467134    63189            21          3                  2
# 99462     794638    50898            24          3                  2
# 145574    794638    50898            24          3                  2
# 311713   1021560    53767             3          3                  2
# 242618   1021560    53767             3          3                  2
# 164581   1112182   202304            84          3                  2
# 273805   1112182   202304            84          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
#
# Las filas duplicadas son idénticas en todas las columnas:
#
# order_id
#
# user_id
#
# order_number
#
# order_dow
#
# order_hour_of_day
#
# days_since_prior_order
#
# Esto significa que el mismo pedido está registrado más de una vez en el conjunto de datos.
#
# No hay diferencias en los valores; son copias exactas de los mismos registros.
#
# Muchos pedidos se realizaron el mismo día de la semana y a la misma hora, lo que coincide con los duplicados exactos que vimos antes.

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.


pedidos_miercoles_2am = orders[(orders['order_dow'] == 3) & (orders['order_hour_of_day'] == 2)]
print(f"Cantidad de pedidos el miércoles a las 2:00 a.m.: {len(pedidos_miercoles_2am)}")
print(pedidos_miercoles_2am.head())
# Out:
# Cantidad de pedidos el miércoles a las 2:00 a.m.: 121
#        order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838    2766110   162084            41          3                  2
# 5156    2190225   138285            18          3                  2
# 15506    553049    58599            13          3                  2
# 18420    382357   120200            19          3                  2
# 24691    690242    77357             2          3                  2
#
#        days_since_prior_order
# 4838                     16.0
# 5156                     11.0
# 15506                     7.0
# 18420                    11.0
# 24691                     9.0

# %% [markdown]
# ¿Qué sugiere este resultado?
#
# Los 121 pedidos no son duplicados exactos; cada uno es único.
#
# El hecho de que muchos caigan en miércoles a las 2:00 a.m. no indica error, sino un patrón de comportamiento de los clientes.
#
# Los duplicados previos eran específicos y no afectan este patrón general.

# %%
# Elimina los pedidos duplicados
duplicados_antes = orders.duplicated().sum()
print(f"Duplicados antes de eliminar: {duplicados_antes}")
orders = orders.drop_duplicates()
# Out:
# Duplicados antes de eliminar: 15

# %%
# Vuelve a verificar si hay filas duplicadas
duplicados_despues = orders.duplicated().sum()
print(f"Duplicados después de eliminar: {duplicados_despues}")
# Out:
# Duplicados después de eliminar: 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
duplicados_order_id = orders['order_id'].duplicated().sum()
print(f"Cantidad de order_id duplicados: {duplicados_order_id}")
# Out:
# Cantidad de order_id duplicados: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# Se eliminaron las filas duplicadas exactas usando .drop_duplicates().
#
# Se verificó que cada order_id sea único, asegurando la integridad de los pedidos.
#
# Se conservaron los valores NaN en days_since_prior_order para que los análisis posteriores puedan identificar correctamente los primeros pedidos de los clientes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Reviewer         </b> <a class="tocSkip"></a>
#
# Bien hecho, dado que todos los duplicados coincidian en el horario y día, es probable que se haya debido a un problema momentaneo en el registro de la data. En un entorno profesional, sería importante revisar que este problema no afecte a muchos registros y ver con el área responsable si esto es un problema conocido o no.
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
duplicados_products = products.duplicated().sum()
print(f"Cantidad de filas duplicadas en 'products': {duplicados_products}")
# Out:
# Cantidad de filas duplicadas en 'products': 0

# %%
# Revisa únicamente si hay ID de productos duplicados
duplicados_product_id = products['product_id'].duplicated().sum()
print(f"Cantidad de product_id duplicados: {duplicados_product_id}")
# Out:
# Cantidad de product_id duplicados: 0

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
products['product_name_upper'] = products['product_name'].str.upper()
duplicados_nombres = products['product_name_upper'].duplicated().sum()
print(f"Cantidad de nombres de productos duplicados: {duplicados_nombres}")
# Out:
# Cantidad de nombres de productos duplicados: 1361

# %%
# Revisa si hay nombres duplicados de productos no faltantes
productos_no_nulos = products[products['product_name'].notnull()]
duplicados_nombres = productos_no_nulos['product_name'].duplicated().sum()
print(f"Cantidad de nombres de productos duplicados (sin valores faltantes): {duplicados_nombres}")
# Out:
# Cantidad de nombres de productos duplicados (sin valores faltantes): 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Filas duplicadas exactas
#
# No se encontraron filas completamente duplicadas (0 filas duplicadas).
#
# Esto indica que cada registro en products es único cuando se consideran todas las columnas juntas.
#
# IDs de productos duplicados
#
# Ningún product_id se repite (0 duplicados).
#
# Cada producto tiene un identificador único, lo cual es importante para mantener la integridad de las relaciones con otras tablas (order_products, aisles, departments).
#
# Nombres de productos duplicados
#
# Se encontraron 1,361 nombres de productos duplicados cuando se consideran mayúsculas/minúsculas.
#
# Esto significa que algunos productos diferentes (con distinto product_id) comparten el mismo nombre, aunque esto no afecta los nombres faltantes, ya que no hay duplicados en valores no nulos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor           </b> <a class="tocSkip"></a>
#
# Muy bien. En este caso, no es anormal encontrar nombres duplicados y no es necesario eliminarlos. Tienen diferente id, por lo tanto, es posible que sean diferentes versiones de un mismo producto.
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
duplicados_departments = departments.duplicated().sum()
print(f"Cantidad de filas duplicadas en 'departments': {duplicados_departments}")
# Out:
# Cantidad de filas duplicadas en 'departments': 0

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
duplicados_department_id = departments['department_id'].duplicated().sum()
print(f"Cantidad de department_id duplicados: {duplicados_department_id}")
# Out:
# Cantidad de department_id duplicados: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Filas duplicadas exactas
#
# No se encontraron filas completamente duplicadas (0 filas duplicadas).
#
# Esto indica que cada registro de departamento es único cuando se consideran todas las columnas (department_id y department).
#
# IDs de departamentos duplicados
#
# Ningún department_id se repite (0 duplicados).
#
# Cada departamento tiene un identificador único, lo cual es fundamental para mantener la integridad al relacionar productos y departamentos.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
duplicados_aisles = aisles.duplicated().sum()
print(f"Cantidad de filas duplicadas en 'aisles': {duplicados_aisles}")
# Out:
# Cantidad de filas duplicadas en 'aisles': 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
duplicados_aisle_id = aisles['aisle_id'].duplicated().sum()
print(f"Cantidad de aisle_id duplicados: {duplicados_aisle_id}")
# Out:
# Cantidad de aisle_id duplicados: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Filas duplicadas exactas
#
# No se encontraron filas completamente duplicadas (0 filas duplicadas).
#
# Esto indica que cada registro de pasillo (aisle) es único cuando se consideran todas las columnas (aisle_id y aisle).
#
# IDs de pasillos duplicados
#
# Ningún aisle_id se repite (0 duplicados).
#
# Cada pasillo tiene un identificador único, lo que garantiza consistencia al unir esta tabla con products.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
duplicados_order_products = order_products.duplicated().sum()
print(f"Cantidad de filas duplicadas en 'order_products': {duplicados_order_products}")
# Out:
# Cantidad de filas duplicadas en 'order_products': 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
duplicados_engañosos = order_products.duplicated(subset=['order_id', 'product_id']).sum()
print(f"Cantidad de duplicados en la combinación order_id + product_id: {duplicados_engañosos}")
# Out:
# Cantidad de duplicados en la combinación order_id + product_id: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Filas duplicadas exactas
#
# No se encontraron filas completamente duplicadas (0 duplicadas).
#
# Esto indica que cada registro de producto dentro de un pedido es único cuando se consideran todas las columnas (order_id, product_id, add_to_cart_order, reordered).
#
# Duplicados en la combinación order_id + product_id
#
# No se encontraron duplicados engañosos (0 duplicados).
#
# Esto confirma que cada producto aparece solo una vez por pedido, lo cual es esencial para análisis de frecuencia de productos, reordenes y comportamiento del cliente.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Buen trabajo en esta sección con la revisión de duplicados
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
valores_ausentes_product_name = products['product_name'].isnull().sum()
print(f"Cantidad de valores ausentes en 'product_name': {valores_ausentes_product_name}")
# Out:
# Cantidad de valores ausentes en 'product_name': 1258

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se encontraron 1,258 valores ausentes en la columna product_name del DataFrame products.
#
# Esto significa que 1,258 productos no tienen un nombre registrado, lo cual puede afectar análisis de frecuencia de productos, reportes de ventas por nombre y uniones con otras tablas.
#
# Los valores ausentes podrían haberse generado por errores en la extracción de datos o registros incompletos del catálogo de productos.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
productos_sin_nombre = products[products['product_name'].isnull()]
aisles_ausentes = productos_sin_nombre['aisle_id'].unique()
print(f"Aisle IDs de productos sin nombre: {aisles_ausentes}")
# Out:
# Aisle IDs de productos sin nombre: [100]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Todos los 1,258 productos sin product_name están asociados al pasillo con aisle_id = 100.
#
# Esto indica que los valores ausentes no están distribuidos aleatoriamente, sino que corresponden a un grupo específico de productos dentro de ese pasillo.
#
# Probablemente, el pasillo 100 represente una categoría especial o temporal de productos cuyo nombre no se registró correctamente en el dataset.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
productos_sin_nombre = products[products['product_name'].isnull()]
departments_ausentes = productos_sin_nombre['department_id'].unique()
print(f"Department IDs de productos sin nombre: {departments_ausentes}")
# Out:
# Department IDs de productos sin nombre: [21]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Todos los 1,258 productos sin product_name están asociados al department_id 21.
#
# Esto indica que los valores ausentes no están distribuidos aleatoriamente, sino que corresponden a un grupo específico de productos dentro de ese departamento.
#
# Combinado con el hallazgo anterior, estos productos también pertenecen al pasillo con aisle_id = 100, lo que sugiere que este conjunto de productos podría representar una categoría especial o temporal cuya información de nombre no se registró correctamente en el dataset.

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
pasillo_100 = aisles[aisles['aisle_id'] == 100]
print("Datos del pasillo con ID 100:")
print(pasillo_100)

departamento_21 = departments[departments['department_id'] == 21]
print("\nDatos del departamento con ID 21:")
print(departamento_21)
# Out:
# Datos del pasillo con ID 100:
#     aisle_id    aisle
# 99       100  missing
#
# Datos del departamento con ID 21:
#     department_id department
# 20             21    missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# El pasillo con aisle_id = 100 tiene el nombre "missing".
#
# El departamento con department_id = 21 también tiene el nombre "missing".
#
# Esto confirma que los 1,258 productos sin product_name pertenecen a un pasillo y departamento cuyo nombre no está registrado correctamente, representado como "missing".
#
# Los valores ausentes no son errores aleatorios, sino que forman parte de una categoría específica de productos sin información completa en el dataset.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products['product_name'] = products['product_name'].fillna('Unknown')
valores_ausentes_post = products['product_name'].isnull().sum()
print(f"Cantidad de valores ausentes en 'product_name' después de rellenar: {valores_ausentes_post}")
# Out:
# Cantidad de valores ausentes en 'product_name' después de rellenar: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Inicialmente, había 1,258 valores ausentes en la columna product_name.
#
# Todos estos productos estaban asociados al pasillo con aisle_id = 100 y al departamento con department_id = 21, cuyos nombres también estaban como "missing".
#
# Para mantener la integridad de la tabla y permitir análisis completos, se reemplazaron los valores ausentes con "Unknown".
#
# Tras esta acción, la columna product_name ya no tiene valores faltantes, como lo confirma el conteo posterior (0 valores ausentes).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Muy bien, debe haber sido un error específico al registrar los datos de ese pasillo y departamento
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
valores_ausentes_days = orders['days_since_prior_order'].isnull().sum()
print(f"Cantidad de valores ausentes en 'days_since_prior_order': {valores_ausentes_days}")
# Out:
# Cantidad de valores ausentes en 'days_since_prior_order': 28817

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
ausentes_no_primer_pedido = orders[(orders['days_since_prior_order'].isnull()) & (orders['order_number'] > 1)]
cantidad_ausentes_no_primer = ausentes_no_primer_pedido.shape[0]
print(f"Cantidad de valores ausentes que NO son del primer pedido: {cantidad_ausentes_no_primer}")
# Out:
# Cantidad de valores ausentes que NO son del primer pedido: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Se encontraron 28,817 valores ausentes en la columna days_since_prior_order.
#
# Al analizar estos valores, todos corresponden al primer pedido de cada cliente (order_number = 1).
#
# No se detectaron valores ausentes que no fueran del primer pedido, lo que indica que los datos son consistentes: el primer pedido naturalmente no tiene un pedido previo, por lo que es lógico que days_since_prior_order sea NaN.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien, es normal que esas filas tengan nulos, son los primeros pedidos de los clientes, y entonces no hay días desde un pedido anterior porque no existe ese pedido anterior.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
valores_ausentes_add = order_products['add_to_cart_order'].isnull().sum()
print(f"Cantidad de valores ausentes en 'add_to_cart_order': {valores_ausentes_add}")
# Out:
# Cantidad de valores ausentes en 'add_to_cart_order': 836

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
min_add_to_cart = order_products['add_to_cart_order'].min()
max_add_to_cart = order_products['add_to_cart_order'].max()

print(f"Valor mínimo en 'add_to_cart_order': {min_add_to_cart}")
print(f"Valor máximo en 'add_to_cart_order': {max_add_to_cart}")
# Out:
# Valor mínimo en 'add_to_cart_order': 1.0
# Valor máximo en 'add_to_cart_order': 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se encontraron 836 valores ausentes en la columna add_to_cart_order.
#
# Los valores válidos en esta columna van de 1 a 64, lo que indica que un pedido puede contener entre 1 y 64 productos en orden secuencial de adición al carrito.
#
# Los valores ausentes representan productos cuyo orden de adición no se registró, lo que podría afectar análisis de patrones de compra y posición de productos en el carrito.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
pedidos_ausentes_add = order_products[order_products['add_to_cart_order'].isnull()]
ids_pedidos_ausentes = pedidos_ausentes_add['order_id'].unique()
print(f"Cantidad de pedidos con valores ausentes en 'add_to_cart_order': {len(ids_pedidos_ausentes)}")
print("Primeros 10 IDs de pedidos con valores ausentes:")
print(ids_pedidos_ausentes[:10])

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor     </b> <a class="tocSkip"></a>
#
# Muy bien, correcta la obtención del listado de pedidos con nulos en `add_to_cart_order`
# </div>

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
resumen = order_products.groupby('order_id').agg(
    productos_count = ('product_id', 'count'),
    tiene_na_add = ('add_to_cart_order', lambda x: x.isnull().any())
)
resumen_pedidos_con_na = resumen[resumen['tiene_na_add']]

min_productos = resumen_pedidos_con_na['productos_count'].min()
max_productos = resumen_pedidos_con_na['productos_count'].max()
todos_mayores_64 = (resumen_pedidos_con_na['productos_count'] > 64).all()

print(f"Min: {min_productos}, Max: {max_productos}, Todos >64?: {todos_mayores_64}")
# Out:
# Min: 65, Max: 127, Todos >64?: True

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# El cálculo de esta parte es incorrecto. Lo que estás haciendo es contar la parte del pedido que tiene nulos. Este código:
#
# ```python
#     order_products[order_products['add_to_cart_order'].isnull()]
#
# ```
#
#
# selecciona solamente las filas que tienen nulos. Sin embargo, en el dataframe `order_products` un pedido tiene varias filas, no necesariamente todas con un nulo, y lo que queremos seleccionar son todas las filas de los pedidos que tienen al menos un nulo en `add_to_cart_order`. Es decir, si un pedido tiene 10 filas, y solo una con nulo, queremos seleccionar las 10 filas, no solo la única que tiene nulo. Para esto, será mejor que uses la lista de la celda anterior con un código así o similar:
#
# ```python
#     pedidos_con_na = order_products[order_products['order_id'].isin(ids_pedidos_ausentes)]
#
# ```
#
# luego sobre ese resultado cuenta los productos que tienen esos pedidos  usando `groupby` y `count()`. Para ver la cantidad mínima y máxima, usa `min()` y `max()` sobre esto último.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor    v2    </b> <a class="tocSkip"></a>
#
# Bien hecho, es probable que el sistema no permita más de 64 tipos de productos en esa columna, por lo que no guarda nada después
#
# </div>

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se encontraron 70 pedidos que contienen al menos un valor ausente en la columna add_to_cart_order.
#
# La cantidad de productos en estos pedidos varía de 1 a 63, lo que indica que no todos los pedidos con valores ausentes son grandes o exceden el valor máximo registrado de 64.
#
# Esto significa que los valores ausentes no se deben únicamente a pedidos muy largos, sino que podrían ser errores de registro o problemas al capturar el orden de adición al carrito.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna(999)
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].astype(int)
valores_ausentes_post = order_products['add_to_cart_order'].isnull().sum()
tipo_columna = order_products['add_to_cart_order'].dtype
print(f"Cantidad de valores ausentes después de rellenar: {valores_ausentes_post}")
print(f"Tipo de dato de la columna 'add_to_cart_order': {tipo_columna}")
# Out:
# Cantidad de valores ausentes después de rellenar: 0
# Tipo de dato de la columna 'add_to_cart_order': int64

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Inicialmente había 836 valores ausentes en la columna add_to_cart_order.
#
# Se reemplazaron todos los valores ausentes con 999 como indicador de ausencia original, y luego se convirtió la columna a tipo entero (int64).
#
# Tras estos cambios, no quedan valores ausentes, lo que asegura que los análisis de secuencia de productos en los carritos se puedan realizar sin errores.

# %% [markdown]
# ## Conclusiones
#
# Duplicados
#
# Se encontraron 15 filas duplicadas en orders, que se eliminaron para garantizar que cada pedido sea único.
#
# No se encontraron duplicados en las tablas products, departments, aisles ni order_products, ni duplicados “engañosos” en combinaciones de IDs.
#
# Esto asegura que los análisis de frecuencia y patrones de pedidos no se vean inflados por registros repetidos.
#
# Valores ausentes
#
# En products, 1,258 nombres de productos estaban ausentes, todos asociados al pasillo con aisle_id = 100 y al departamento con department_id = 21, cuyos nombres también eran "missing".
#
# Se rellenaron estos valores con "Unknown", dejando la columna completamente limpia.
#
# En orders, 28,817 valores ausentes en days_since_prior_order correspondían únicamente al primer pedido de cada cliente, lo cual es lógico y no requiere modificación.
#
# En order_products, 836 valores ausentes en add_to_cart_order fueron reemplazados con 999 y la columna se convirtió a tipo entero (int64), dejando la columna consistente y lista para análisis.
#
# Hallazgos importantes
#
# Los valores ausentes y duplicados no se distribuyen aleatoriamente, sino que tienen patrones específicos (por ejemplo, productos del pasillo/dep "missing" y primeros pedidos de clientes).
#
# Estas observaciones nos permiten realizar un preprocesamiento informado, preservando la integridad de los datos y asegurando que los análisis posteriores sean precisos.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
# Revisar rango de 'order_hour_of_day'
min_hour = orders['order_hour_of_day'].min()
max_hour = orders['order_hour_of_day'].max()

print(f"Rango de 'order_hour_of_day': {min_hour} a {max_hour}")
# Out:
# Rango de 'order_hour_of_day': 0 a 23

# %%
min_dow = orders['order_dow'].min()
max_dow = orders['order_dow'].max()

print(f"Rango de 'order_dow': {min_dow} a {max_dow}")
# Out:
# Rango de 'order_dow': 0 a 6

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los valores en order_hour_of_day están entre 0 y 23, lo que corresponde correctamente a las 24 horas del día.
#
# Los valores en order_dow están entre 0 y 6, lo que coincide con los días de la semana (0 = domingo, 6 = sábado).
#
# Esto indica que los datos de hora y día de los pedidos son consistentes y razonables, sin registros fuera de los rangos esperados.
#
# Por lo tanto, estos campos son fiables para análisis posteriores de patrones de pedidos por hora y por día de la semana.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Correcto, muy bien con el cálculo. Ahora estamos seguros que tenemos datos que hacen sentido en estas columnas.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
usuarios_por_hora = orders.groupby('order_hour_of_day')['user_id'].nunique()
print(usuarios_por_hora)

plt.figure(figsize=(12,6))
sns.barplot(x=usuarios_por_hora.index, y=usuarios_por_hora.values, palette="viridis")
plt.xlabel("Hora del día")
plt.ylabel("Usuarios únicos")
plt.title("Usuarios únicos que hacen pedidos por hora del día")
plt.xticks(range(0,24))
plt.show()
# Out:
# order_hour_of_day
# 0      2991
# 1      1671
# 2       958
# 3       744
# 4       735
# 5      1281
# 6      3757
# 7     10993
# 8     20268
# 9     28112
# 10    32195
# 11    32660
# 12    31754
# 13    32433
# 14    32797
# 15    32894
# 16    31579
# 17    26825
# 18    21795
# 19    17026
# 20    12891
# 21     9806
# 22     7670
# 23     5167
# Name: user_id, dtype: int64

# %% [markdown]
# Escribe aquí tus conclusiones
#
# La actividad de los clientes empieza baja durante la madrugada (0–5 h), con menos de 1,300 usuarios únicos realizando pedidos por hora.
#
# A partir de las 6 a.m., los pedidos comienzan a aumentar notablemente, alcanzando un pico entre las 10 a.m. y las 4 p.m., donde más de 30,000 personas realizan pedidos en cada hora.
#
# Después de las 5 p.m., la actividad disminuye progresivamente, con una caída significativa durante la noche (21–23 h).
#
# Esto refleja patrones de compra típicos, donde la mayoría de los clientes hacen pedidos durante el día y temprano en la tarde, y muy pocos durante la madrugada.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
#
# Bien hecho con este gráfico, se observa que hay pedidos nocturnos y el peak llega a las 10 de la mañana
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
usuarios_por_dia = orders.groupby('order_dow')['user_id'].nunique()
print(usuarios_por_dia)

plt.figure(figsize=(10,5))
sns.barplot(x=usuarios_por_dia.index, y=usuarios_por_dia.values, palette="magma")
plt.xlabel("Día de la semana (0=Domingo)")
plt.ylabel("Usuarios únicos")
plt.title("Usuarios únicos que hacen pedidos por día de la semana")
plt.show()
# Out:
# order_dow
# 0    57661
# 1    56479
# 2    48587
# 3    45331
# 4    44281
# 5    46127
# 6    45604
# Name: user_id, dtype: int64

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los datos muestran que la mayoría de los clientes realizan pedidos durante el fin de semana y lunes, siendo el domingo (`0`) el día con más usuarios únicos (57,661).
#
# Los días con menos actividad son miércoles (`3`) y jueves (`4`), con alrededor de 45,000 usuarios cada uno.
#
# Esto refleja un patrón típico de compras de víveres, donde los clientes tienden a hacer pedidos antes o durante el fin de semana para abastecerse.
#
# Estos hallazgos pueden ser útiles para planificar logística, promociones y disponibilidad de productos, priorizando los días de mayor demanda.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor              </b><a class="tocSkip"></a>
#
# Correcto, se aprecia que el domingo es el día con mayor cantidad de pedidos. Salvo el lunes, el resto de los días son muy parejos.
#
#
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
tiempo_entre_pedidos = orders['days_since_prior_order'].dropna()

# Valores mínimo y máximo
min_dias = tiempo_entre_pedidos.min()
max_dias = tiempo_entre_pedidos.max()
print(f"Tiempo mínimo entre pedidos: {min_dias} días")
print(f"Tiempo máximo entre pedidos: {max_dias} días")

# Histograma para visualizar la distribución
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.histplot(tiempo_entre_pedidos, bins=30, kde=False, color="skyblue")
plt.xlabel("Días desde el pedido anterior")
plt.ylabel("Número de pedidos")
plt.title("Distribución del tiempo hasta el siguiente pedido")
plt.show()
# Out:
# Tiempo mínimo entre pedidos: 0.0 días
# Tiempo máximo entre pedidos: 30.0 días

# %% [markdown]
# Escribe aquí tus conclusiones
#
# El tiempo mínimo entre pedidos es 0 días lo que indica que algunos clientes realizaron más de un pedido el mismo día
#
# El tiempo máximo entre pedidos es 30 días mostrando que otros clientes esperan hasta un mes antes de hacer otro pedido.
#
# La mayoría de los pedidos probablemente se concentran en intervalos regulares como semanal o mensual, reflejando hábitos típicos de compra de víveres.
#
# Estos hallazgos permiten comprender la frecuencia de compra de los clientes lo que es útil para planificar promociones, recordatorios o estrategias de fidelización.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Muy bien, el gráfico es correcto. Nota que el tiempo de 30 días es muy alto, esto es sospechoso ya que es el valor más grande que se registra y es anormalmente grande respecto a los valores que vienen justo antes. Probablemente se debe a que el sistema no registra más de 30 días entre compras y todas las que son de más de ese tiempo las guarda como 30.
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
orders_wed = orders[orders['order_dow'] == 3]
orders_sat = orders[orders['order_dow'] == 6]

# %%
wed_counts = orders_wed['order_hour_of_day'].value_counts().sort_index()
sat_counts = orders_sat['order_hour_of_day'].value_counts().sort_index()

# %%
df_comp = pd.DataFrame({
    'Hora del día': wed_counts.index,
    'Miércoles': wed_counts.values,
    'Sábado': sat_counts.reindex(wed_counts.index, fill_value=0).values
})

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Hora del día', y='Miércoles', data=df_comp, color='skyblue', label='Miércoles')
sns.barplot(x='Hora del día', y='Sábado', data=df_comp, color='salmon', alpha=0.7, label='Sábado')

plt.title("Distribución de pedidos por hora del día (Miércoles vs Sábado)")
plt.xlabel("Hora del día")
plt.ylabel("Número de pedidos")
plt.legend()
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Durante la madrugada (0–5 h), la cantidad de pedidos es muy baja para ambos días, casi inexistente.
#
# A partir de las 6 a.m., los pedidos comienzan a aumentar considerablemente.
#
# El sábado muestra más pedidos en las horas de la mañana (8–11 h) que el miércoles, lo que sugiere que muchas personas aprovechan el fin de semana para hacer compras tempranas.
#
# En cambio, el miércoles presenta un pico más moderado alrededor del mediodía (11–14 h), probablemente asociado a pedidos realizados en pausas laborales.
#
# Después de las 18 h, ambos días disminuyen su actividad de manera progresiva.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho, muy bien con la comparación entre los días
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
pedidos_por_cliente = orders.groupby('user_id')['order_id'].count()

# %%
plt.figure(figsize=(10,6))
sns.histplot(pedidos_por_cliente, bins=30, color='mediumseagreen', kde=False)

plt.title("Distribución del número de pedidos por cliente")
plt.xlabel("Número de pedidos realizados por cliente")
plt.ylabel("Cantidad de clientes")
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# La distribución está fuertemente sesgada hacia la izquierda, lo que indica que la mayoría de los clientes ha hecho pocos pedidos.
#
# El grupo más grande corresponde a clientes con entre 1 y 5 pedidos.
#
# A medida que aumenta el número de pedidos, la cantidad de clientes disminuye drásticamente.
#
# Muy pocos usuarios llegan a hacer más de 30 pedidos, lo que sugiere un grupo reducido de clientes leales o recurrentes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
# Excelente, muy bien con el resultado. Observamos que la cantidad de pedidos de cliente es estrictamente decreciente.
#
#
#
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
top20_products = order_products['product_id'].value_counts().head(20)

# %%
top20_df = pd.DataFrame({
    'product_id': top20_products.index,
    'total_orders': top20_products.values
})

# %%
top20_df = top20_df.merge(products[['product_id', 'product_name']], on='product_id')
print(top20_df)
# Out:
#     product_id  total_orders              product_name
# 0        24852         66050                    Banana
# 1        13176         53297    Bag of Organic Bananas
# 2        21137         37039      Organic Strawberries
# 3        21903         33971      Organic Baby Spinach
# 4        47209         29773      Organic Hass Avocado
# 5        47766         24689           Organic Avocado
# 6        47626         21495               Large Lemon
# 7        16797         20018              Strawberries
# 8        26209         19690                     Limes
# 9        27845         19600        Organic Whole Milk
# 10       27966         19197       Organic Raspberries
# 11       22935         15898      Organic Yellow Onion
# 12       24964         15292            Organic Garlic
# 13       45007         14584          Organic Zucchini
# 14       39275         13879       Organic Blueberries
# 15       49683         13675            Cucumber Kirby
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los productos más solicitados son alimentos básicos y frescos, especialmente frutas y verduras orgánicas, como plátanos, fresas, espinacas y aguacates.
#
# Esto indica una alta preferencia por productos naturales y saludables, tendencia coherente con los hábitos de compra actuales.
#
# La recurrencia de estos productos también sugiere que son bienes de consumo frecuente, necesarios para el día a día.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Correcto,  se ve que predominan los productos orgánicos y de uso diario
#
# </div>

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
articulos_por_pedido = order_products.groupby('order_id')['product_id'].count()

# %%
print("=== Estadísticas descriptivas ===")
print(articulos_por_pedido.describe())
# Out:
# === Estadísticas descriptivas ===
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: product_id, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(articulos_por_pedido, bins=30, color='slateblue', kde=False)
plt.title("Distribución del número de artículos por pedido", fontsize=14)
plt.xlabel("Número de artículos por pedido")
plt.ylabel("Cantidad de pedidos")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los resultados muestran que los clientes compran en promedio 10 artículos por pedido, aunque existe una gran variabilidad (desviación estándar de aproximadamente 7.5).
#
# El pedido más pequeño contiene solo 1 producto, mientras que el más grande llega a 127 artículos, aunque estos casos son poco frecuentes.
#
# El 50 % de los pedidos tiene 8 o menos artículos, y el 75 % tiene 14 o menos, lo que indica que la mayoría de los clientes realiza compras pequeñas o medianas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor      </b> <a class="tocSkip"></a>
#
# Muy bien con el gráfico, está correcto. Vemos que hay una distribución concentrada en los primeros valores, pero luego cae muy rápido
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
merged = order_products.merge(products[['product_id','product_name']], on='product_id', how='left')

# %%
top20 = (
    merged[merged['reordered'] == 1]
    .groupby(['product_id', 'product_name'])
    .size()
    .reset_index(name='reorder_count')
    .sort_values('reorder_count', ascending=False)
    .head(20)
)

# %%
print("=== 20 productos más frecuentemente reordenados ===")
print(top20.to_string(index=False))
# Out:
# === 20 productos más frecuentemente reordenados ===
#  product_id             product_name  reorder_count
#       24852                   Banana          55763
#       13176   Bag of Organic Bananas          44450
#       21137     Organic Strawberries          28639
#       21903     Organic Baby Spinach          26233
#       47209     Organic Hass Avocado          23629
#       47766          Organic Avocado          18743
#       27845       Organic Whole Milk          16251
#       47626              Large Lemon          15044
#       27966      Organic Raspberries          14748
#       16797             Strawberries          13945
#       26209                    Limes          13327
#       22935     Organic Yellow Onion          11145
#       24964           Organic Garlic          10411
#       45007         Organic Zucchini          10076
#       49683           Cucumber Kirby           9538
#       28204       Organic Fuji Apple           8989
# ...

# %%
def trunc(name, n=60):
    return name if len(name) <= n else name[:n-3] + '...'

top20['label'] = top20['product_name'].apply(lambda s: trunc(s, 60))
top20_plot = top20.sort_values('reorder_count')  # ordenar ascendente para barh

plt.figure(figsize=(10,8))
plt.barh(top20_plot['label'], top20_plot['reorder_count'])
plt.xlabel('Veces reordenado')
plt.title('Top 20 productos más reordenados (count de reorders)')
# Anotar valores a la derecha de cada barra
maxv = top20_plot['reorder_count'].max()
for i, v in enumerate(top20_plot['reorder_count']):
    plt.text(v + maxv * 0.01, i, str(v), va='center', fontsize=9)
plt.tight_layout()

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los resultados muestran que los productos más frecuentemente reordenados corresponden principalmente a frutas y verduras frescas, especialmente las versiones orgánicas.
#
# Los artículos como Bananas, Bag of Organic Bananas, Organic Strawberries y Organic Baby Spinach encabezan la lista, con decenas de miles de reordenes cada uno.
#
# Esto sugiere que los clientes tienden a recomprar productos de consumo básico y frecuente, especialmente alimentos perecederos de uso diario. Además, la presencia dominante de productos “orgánicos” indica una preferencia creciente por opciones saludables entre los consumidores.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho, vemos que los productos más pedidos también son los más reordenados
#
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
reorder_rate = (
    order_products.groupby('product_id')['reordered']
    .agg(['sum', 'count'])
    .rename(columns={'sum': 'reordered_sum', 'count': 'total_orders'})
)

# %%
reorder_rate['reorder_ratio'] = reorder_rate['reordered_sum'] / reorder_rate['total_orders']

# %%
print("=== Tasa de repetición de pedido por producto ===")
print(reorder_rate.head(20))
# Out:
# === Tasa de repetición de pedido por producto ===
#             reordered_sum  total_orders  reorder_ratio
# product_id
# 1                     158           280       0.564286
# 2                       0            11       0.000000
# 3                      31            42       0.738095
# 4                      25            49       0.510204
# 7                       1             2       0.500000
# 8                       6            19       0.315789
# 9                      16            21       0.761905
# 10                    151           337       0.448071
# 11                     10            16       0.625000
# 12                     16            41       0.390244
# 13                      1             2       0.500000
# 14                      0             3       0.000000
# 17                      0             1       0.000000
# 18                      8            15       0.533333
# 19                      0             1       0.000000
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# En el análisis de la tasa de repetición por producto se observa que los valores de reorder_ratio varían significativamente entre productos, desde 0 (nunca se reordenaron) hasta más de 0.7 (se reordenaron la mayoría de las veces).
#
# Esto indica que algunos artículos tienen una alta fidelidad de recompra, probablemente porque son productos de consumo frecuente, como alimentos básicos o frutas.
# Por otro lado, los productos con tasa de repetición baja (cercana a 0) podrían corresponder a artículos comprados ocasionalmente o de prueba, lo que refleja hábitos de compra más variados.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Muy bien, correcto. También se puede usar la media de `reordered` para este cálculo.
#
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
user_reorder_rate = (
    order_products
    .merge(orders[['order_id', 'user_id']], on='order_id', how='left')
    .groupby('user_id')['reordered']
    .agg(['sum', 'count'])
    .rename(columns={'sum': 'reordered_sum', 'count': 'total_products'})
)

# %%
user_reorder_rate['reorder_ratio'] = (
    user_reorder_rate['reordered_sum'] / user_reorder_rate['total_products']
)

print("=== Tasa de repetición de pedidos por usuario ===")
print(user_reorder_rate.head(20))
# Out:
# === Tasa de repetición de pedidos por usuario ===
#          reordered_sum  total_products  reorder_ratio
# user_id
# 2                    1              26       0.038462
# 4                    0               2       0.000000
# 5                    8              12       0.666667
# 6                    0               4       0.000000
# 7                   13              14       0.928571
# 11                   3              15       0.200000
# 12                   3              12       0.250000
# 13                  13              23       0.565217
# 14                  22              61       0.360656
# 15                   7              13       0.538462
# 16                  17              32       0.531250
# 17                  38              53       0.716981
# 19                  14              48       0.291667
# 20                   0               4       0.000000
# 21                   8              20       0.400000
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Algunos usuarios, como el ID 7 o el 22, tienen tasas muy altas (mayores al 90 %), lo que indica que suelen pedir repetidamente los mismos productos.
# Otros, en cambio, presentan valores bajos o incluso 0, lo que sugiere que están explorando nuevos artículos o que son clientes nuevos con pocos pedidos anteriores.
#
# En general, esta métrica revela distintos patrones de comportamiento:
#
# Clientes fieles a ciertos productos, que reordenan con frecuencia.
#
# Clientes ocasionales o exploradores, que prueban artículos nuevos en cada compra.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho, muy bien con el cálculo por el lado de los usuarios.
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
primeros_productos = order_products[order_products['add_to_cart_order'] == 1]

# %%
top20_first = (
    primeros_productos
    .groupby('product_id')
    .size()
    .reset_index(name='first_count')
    .merge(products[['product_id','product_name']], on='product_id', how='left')
    .sort_values('first_count', ascending=False)
    .head(20)
)

# %%
print("=== Top 20 productos más añadidos primero al carrito ===")
print(top20_first[['product_id','product_name','first_count']])
# Out:
# === Top 20 productos más añadidos primero al carrito ===
#        product_id                 product_name  first_count
# 13414       24852                       Banana        15562
# 7127        13176       Bag of Organic Bananas        11026
# 15028       27845           Organic Whole Milk         4363
# 11384       21137         Organic Strawberries         3946
# 25439       47209         Organic Hass Avocado         3390
# 11786       21903         Organic Baby Spinach         3336
# 25732       47766              Organic Avocado         3044
# 10622       19660                 Spring Water         2336
# 9050        16797                 Strawberries         2308
# 15102       27966          Organic Raspberries         2024
# 24024       44632   Sparkling Water Grapefruit         1914
# 26519       49235          Organic Half & Half         1797
# 25658       47626                  Large Lemon         1737
# 115           196                         Soda         1733
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los resultados muestran que los productos que los clientes suelen poner primero en sus carritos son principalmente frutas y productos de consumo diario, especialmente Bananas y Bag of Organic Bananas, que encabezan la lista con más de 15,000 y 11,000 veces respectivamente.
#
# Otros artículos frecuentes incluyen Organic Whole Milk, Organic Strawberries, Organic Hass Avocado y Organic Baby Spinach, así como algunas bebidas como Spring Water y Soda.
#
# Esto refleja un patrón de compra donde los clientes tienden a añadir primero productos esenciales y frescos, probablemente los que consideran prioritarios para su compra.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Buen trabajo. Al parecer los productos orgánicos representan el grueso de ventas en varios aspectos
#
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# El análisis del conjunto de estos datos permitió explorar los hábitos de compra de los clientes y comprender mejor tanto patrones de comportamiento individual como tendencias generales de los productos.
#
# Durante el preprocesamiento, se identificaron y corrigieron valores duplicados y ausentes, asegurando que los datos fueran consistentes y listos para el análisis. Por ejemplo:
#
# Se eliminaron filas duplicadas en la tabla orders.
#
# Se rellenaron los nombres de productos ausentes con "Unknown".
#
# Se reemplazaron valores faltantes en add_to_cart_order con un valor indicativo (999) y se convirtieron a tipo entero.
#
# En el análisis exploratorio se observaron patrones claros de comportamiento:
#
# La mayoría de los pedidos se realizan durante el día, con picos entre 10 a.m. y 4 p.m., y menos actividad durante la madrugada.
#
# Los miércoles y sábados presentan diferencias en la distribución horaria de pedidos, reflejando hábitos de compra distintos según el día de la semana.
#
# La mayoría de los clientes hace pedidos pequeños o medianos, con un promedio de aproximadamente 10 productos por pedido.
#
# Respecto a los productos y hábitos de recompra:
#
# Los artículos más reordenados y los que se ponen primero en el carrito tienden a ser frutas, verduras y lácteos, especialmente versiones orgánicas.
#
# La tasa de repetición por producto muestra que algunos artículos son altamente recurrentes, mientras que otros apenas se reordenan.
#
# La tasa de repetición por cliente revela diferencias importantes: algunos usuarios son muy fieles a ciertos productos, mientras que otros experimentan con artículos nuevos en cada compra.
#
# En general, este análisis proporciona información estratégica para Instacart:
#
# Optimización de inventario en productos de alta demanda.
#
# Diseño de promociones y recomendaciones personalizadas según patrones de recompra.
#
# Planificación de campañas de marketing dirigidas a clientes recurrentes o exploradores.
#
# El proyecto demuestra cómo la limpieza de datos y el análisis exploratorio pueden transformar un conjunto de datos complejo en información accionable, ofreciendo insights valiosos sobre la conducta del consumidor y las preferencias de compra.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho con estas conclusiones. Podrías mejorarlas incluyendo algunos valores de las métricas más importantes, así las afirmaciones realizadas estarían mejor apoyadas en hechos.
#
# </div>
